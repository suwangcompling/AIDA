# %%
import sys
sys.path.insert(0, "/work/04233/sw33286/AIDA-SCRIPTS")

# %%
import dill
import random
import nltk
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
import tensorflow.contrib.seq2seq as seq2seq
from tensorflow.contrib.layers import safe_embedding_lookup_sparse as embedding_lookup_unique
from tensorflow.contrib.rnn import LSTMCell, LSTMStateTuple, GRUCell

from helpers import Indexer
from helpers import batch
# from nltk.corpus import brown
from collections import defaultdict, Counter
from sklearn.cluster import KMeans

# %% [markdown]
# ### Prepare data

# %%
ANIMAL = ['cat','dog','pig','deer','mouse']
VEHICLE = ['car','bike','motorcycle','train','bus']
TYPE2VOCAB = {'animal':ANIMAL, 'vehicle':VEHICLE}
VOCAB = ANIMAL + VEHICLE

indexer = Indexer()
indexer.get_index('PAD')
indexer.get_index('EOS')
for word in VOCAB:
    indexer.get_index(word)

# %%
FROM_LEN = 3
TO_LEN = 5

# <== generate clean sentences

# def generate_sent(from_len, to_len, sem_type): 
#     length = np.random.randint(from_len, to_len)
#     return np.random.choice(TYPE2VOCAB[sem_type], length)

# def generate_data(n, from_len=FROM_LEN, to_len=TO_LEN):
#     assert n%2==0 # half for each type.
#     data_X, data_y = [], [] # data_y: for clustering supervision later.
#     for _ in range(n//2):
#         data_X.append(to_code(generate_sent(from_len,to_len,'animal')))
#         data_X.append(to_code(generate_sent(from_len,to_len,'vehicle')))
#         data_y.append(0)
#         data_y.append(1)
#     data_X, data_y = np.array(data_X), np.array(data_y)
#     indices = list(range(n))
#     random.shuffle(indices)
#     return data_X[indices], data_y[indices]

# <== generate vocab-mixed sentences

def generate_sent(from_len, to_len, sem_type1, sem_type2, noise_ratio=0.3): 
    length = np.random.randint(from_len, to_len)
    noise_length = int(np.floor(length*noise_ratio))
    mix = np.concatenate((np.random.choice(TYPE2VOCAB[sem_type2], noise_length),
                          np.random.choice(TYPE2VOCAB[sem_type1], length-noise_length)))
    random.shuffle(mix)
    return mix

def generate_data(n, from_len=FROM_LEN, to_len=TO_LEN):
    assert n%2==0 # half for each type.
    data_X, data_y = [], [] # data_y: for clustering supervision later.
    for _ in range(n//2):
        data_X.append(to_code(generate_sent(from_len,to_len,'animal','vehicle')))
        data_X.append(to_code(generate_sent(from_len,to_len,'vehicle','animal')))
        data_y.append(0)
        data_y.append(1)
    data_X, data_y = np.array(data_X), np.array(data_y)
    indices = list(range(n))
    random.shuffle(indices)
    return data_X[indices], data_y[indices]

def to_code(sent):
    return [indexer.get_index(word) for word in sent]

def to_sent(code):
    return list(map(lambda w_idx:indexer.get_object(w_idx), code))

# %%
class DataIterator:
    
    def __init__(self, X, y, shuf=False):
        self.X = X
        self.y = y
        self.cursor = 0
        self.epoch = 0
        self.shuf = shuf
        self.size = len(self.X)
        self.indices = list(range(len(self.X)))
    
    def shuffle(self):
        random.shuffle(self.indices)
        self.X = self.X[self.indices]
        self.y = self.y[self.indices]
    
    def get_batch(self, k):
        if self.cursor+k > self.size:
            if self.shuf:
                self.shuffle()
            self.epoch += 1
            self.cursor = 0
        batch_X = self.X[self.cursor:self.cursor+k]
        batch_y = self.y[self.cursor:self.cursor+k]
        self.cursor += k
        return batch_X, batch_y

# %%
# %%time

glove_path = "/work/04233/sw33286/AIDA-DATA/glove.6B.300d.txt"

WORD2EMB = dict()
with open(glove_path, 'r') as f:
    for line in f:
        line = line.split(' ')
        if line[0] not in VOCAB:
            continue
        WORD2EMB[line[0]] = np.array(list(map(lambda n_str:float(n_str), line[1:])))
print('Vocab size = {}, retained = {}'.format(len(VOCAB), len(WORD2EMB)))
# Out:
# Vocab size = 10, retained = 10
# CPU times: user 7.59 s, sys: 393 ms, total: 7.98 s
# Wall time: 7.92 s

# %%
glove_embs = []
for i,w in indexer.ints_to_objs.items():
    if w in ['PAD','EOS']:
        glove_embs.insert(i, np.random.random(300))
    else:
        glove_embs.insert(i, WORD2EMB[w])
glove_embs = np.array(glove_embs)

# %% [markdown]
# ### Autoencoder+K-means Graph

# %%
tf.reset_default_graph()
sess = tf.Session()



batch_size = 100 # big batch for easier clustering
vocab_size = len(indexer)
# embed_size = 20
encoder_hidden_size = 20
decoder_hidden_size = encoder_hidden_size*2

num_cls = 2

encoder_cell = LSTMCell(encoder_hidden_size)
decoder_cell = LSTMCell(decoder_hidden_size)

encoder_inputs = tf.placeholder(tf.int32, [None, None], name='encoder_inputs')
encoder_inputs_length = tf.placeholder(tf.int32, [None,], name='encoder_inputs_length')
decoder_targets = tf.placeholder(tf.int32, [None, None], name='decoder_targets')
decoder_targets_length = tf.placeholder(tf.int32, [None,], name='decoder_targets_length')

with tf.name_scope('DecoderTrainFeeds'):
    sequence_size, batch_size_ = tf.unstack(tf.shape(decoder_targets))
    EOS_SLICE = tf.ones([1, batch_size_], dtype=tf.int32) * indexer.get_index('EOS')
    PAD_SLICE = tf.ones([1, batch_size_], dtype=tf.int32) * indexer.get_index('PAD')
    decoder_train_inputs = tf.concat([EOS_SLICE, decoder_targets], axis=0) # [max-time+1, batch_size]
    decoder_train_length = decoder_targets_length + 1
    decoder_train_targets = tf.concat([decoder_targets, PAD_SLICE], axis=0) # [max-time+2, batch_size]
    decoder_train_targets_seq_len,_ = tf.unstack(tf.shape(decoder_train_targets))
    decoder_train_targets_eos_mask = tf.one_hot(decoder_train_length-1, # basically batch_size
                                                decoder_train_targets_seq_len, # depth=max-time+2
                                                on_value=indexer.get_index('EOS'), 
                                                off_value=indexer.get_index('PAD'),
                                                dtype=tf.int32)
    decoder_train_targets_eos_mask = tf.transpose(decoder_train_targets_eos_mask, [1,0])
    decoder_train_targets = tf.add(decoder_train_targets,
                                   decoder_train_targets_eos_mask)
    loss_weights = tf.ones([
        batch_size,
        tf.reduce_max(decoder_train_length)
    ], dtype=tf.float32, name='loss_weights')
    
with tf.variable_scope('embedding') as scope:
    embedding_matrix = tf.get_variable('embedding_matrix', glove_embs.shape, 
                                       initializer=tf.contrib.layers.xavier_initializer())
    glove_feed = tf.placeholder(tf.float32, glove_embs.shape)
    glove_init = embedding_matrix.assign(glove_feed)
    encoder_inputs_embedded = tf.nn.embedding_lookup(embedding_matrix, encoder_inputs)
    decoder_train_inputs_embedded = tf.nn.embedding_lookup(embedding_matrix, decoder_train_inputs)
    
with tf.variable_scope('BidirectionalEncoder') as scope:
    encoder_cell = LSTMCell(encoder_hidden_size)
    ((encoder_fw_outputs,encoder_bw_outputs),
     (encoder_fw_state,encoder_bw_state)) = (
        tf.nn.bidirectional_dynamic_rnn(cell_fw=encoder_cell,
                                        cell_bw=encoder_cell,
                                        inputs=encoder_inputs_embedded,
                                        sequence_length=encoder_inputs_length,
                                        dtype=tf.float32, time_major=True)
    )
    encoder_outputs = tf.concat((encoder_fw_outputs, encoder_bw_outputs), 2) # [max-time, batch_size, hid_size]
    if isinstance(encoder_fw_state, LSTMStateTuple):
        encoder_state_c = tf.concat((encoder_fw_state.c, encoder_bw_state.c), 1, name='bidirectional_concat_c')
        encoder_state_h = tf.concat((encoder_fw_state.h, encoder_bw_state.h), 1, name='bidirectional_concat_h')
        encoder_state = LSTMStateTuple(c=encoder_state_c, h=encoder_state_h)
    elif isinstance(encoder_fw_state, tf.Tensor):
        encoder_state = tf.concat((encoder_fw_state, encoder_bw_state), 1, name='bidirectional_concat')
        
with tf.variable_scope('Decoder') as scope:
    # attention free setup.
    def output_fn(outputs):
        return tf.contrib.layers.linear(outputs, vocab_size, scope=scope)
    attention_states = tf.transpose(encoder_outputs, [1,0,2]) # [batch_size,max-time,hidden_size]
    (attention_keys,
    attention_values,
    attention_score_fn,
    attention_construct_fn) = seq2seq.prepare_attention(
        attention_states=attention_states,
        attention_option='bahdanau',
        num_units=decoder_hidden_size
    )
    decoder_fn_train = seq2seq.attention_decoder_fn_train(
        encoder_state=encoder_state,
        attention_keys=attention_keys,
        attention_values=attention_values,
        attention_score_fn=attention_score_fn,
        attention_construct_fn=attention_construct_fn,
        name='attention_decoder'
    )
    decoder_fn_inference = seq2seq.attention_decoder_fn_inference(
        output_fn=output_fn,
        encoder_state=encoder_state,
        attention_keys=attention_keys,
        attention_values=attention_values,
        attention_score_fn=attention_score_fn,
        attention_construct_fn=attention_construct_fn,
        embeddings=embedding_matrix,
        start_of_sequence_id=indexer.get_index('EOS'),
        end_of_sequence_id=indexer.get_index('EOS'),
        maximum_length=tf.reduce_max(encoder_inputs_length) + 3,
        num_decoder_symbols=vocab_size
    )
    
    (decoder_outputs_train,
     decoder_state_train,
     decoder_context_state_train) = (
        seq2seq.dynamic_rnn_decoder(
            cell=decoder_cell,
            decoder_fn=decoder_fn_train,
            inputs=decoder_train_inputs_embedded,
            sequence_length=decoder_train_length,
            time_major=True,
            scope=scope
        )
    )
    decoder_logits_train = output_fn(decoder_outputs_train)
    decoder_prediction_train = tf.argmax(decoder_logits_train, axis=-1, name='decoder_prediction_train')
    scope.reuse_variables()
    (decoder_logits_inference,
     decoder_state_inference,
     decoder_context_state_inference) = (
        seq2seq.dynamic_rnn_decoder(
            cell=decoder_cell,
            decoder_fn=decoder_fn_inference,
            time_major=True,
            scope=scope
        )
    )
    decoder_prediction_inference = tf.argmax(decoder_logits_inference, axis=-1, name='decoder_prediction_inference')

##### ADD ENCODING BLOC #####

encoded_inputs = encoder_state.h # [batch_size, hid_size]
# bc,hd = tf.unstack(tf.shape(encoded_inputs))
s = tf.placeholder(tf.float32, [None, num_cls]) # None = batch_size
M = tf.placeholder(tf.float32, [num_cls, encoder_hidden_size*2]) # bidirectional encoding
sM = tf.matmul(s, M) # [batch_size, hid_size]
km_loss = tf.reduce_sum(tf.sqrt(tf.reduce_sum(tf.square(tf.subtract(encoded_inputs, sM)),1)))

#############################
    
logits = tf.transpose(decoder_logits_train, [1,0,2])
targets = tf.transpose(decoder_train_targets, [1,0])
reconstr_loss = seq2seq.sequence_loss(logits=logits, targets=targets, weights=loss_weights)
total_loss = reconstr_loss + km_loss

# train_op = tf.train.AdamOptimizer(1e-4).minimize(reconstr_loss)
train_op = tf.train.AdamOptimizer(1e-4).minimize(total_loss)

sess.run(tf.global_variables_initializer())

# %%
# K-Means tools

def one_hot(idxs,depth,dtype):
    length = len(idxs)
    res = np.zeros((length,depth),dtype=dtype)
    res[np.arange(length), idxs] = 1.0
    return res

def km_clust(x, k, out_dtype='float32'): # x = encoded_inputs.eval(), [batch_size, hid_size]
    km = KMeans(n_clusters=k).fit(x)
    assignments = one_hot(km.labels_,k,dtype=out_dtype)
    centroids = np.array(km.cluster_centers_,dtype=out_dtype)
    return assignments, centroids

def clustering_accurracy(true, onehot_pred, num_labels):
    # true: a list of true labels (binary); 
    # onehot_pred: n * num_class 1-hot assignments.
    return max((np.argmax(onehot_pred, axis=1)==true).sum()/num_labels,
               (np.argmax(onehot_pred, axis=1)==1-true).sum()/num_labels)

# %%
def make_train_inputs(input_seq, target_seq):
    inputs_, inputs_length_ = batch(input_seq)
    targets_, targets_length_ = batch(target_seq)
    return {
        encoder_inputs: inputs_,
        encoder_inputs_length: inputs_length_,
        decoder_targets: targets_,
        decoder_targets_length: targets_length_,
    }

# %%
data_size = 10000
X, y = generate_data(data_size)

# %%
# Autoencoder+K-means cotraining

num_epochs = 100
loss_track = []
accuracy_track = []
verbose = 100 # 100 batches

try:
    data_iter = DataIterator(X, y, shuf=True)
    batch_count = 0
    curr_epoch = -1
    while data_iter.epoch<num_epochs:
        if data_iter.epoch>curr_epoch:
            curr_epoch = data_iter.epoch
            print('Epoch {}'.format(curr_epoch+1))
            print('\n')
        batch_count += 1
        batch_inputs, batch_labels = data_iter.get_batch(batch_size)
        fd = make_train_inputs(batch_inputs, batch_inputs)
        x = sess.run(encoded_inputs, fd)
        s_, M_ = km_clust(x, num_cls)
        fd_add = {s:s_,M:M_}
        fd.update(fd_add)
        _, l = sess.run([train_op, total_loss], fd)
        loss_track.append(l)
        a = clustering_accurracy(batch_labels,s_,batch_size)
        accuracy_track.append(a)
        if batch_count%verbose==0:
            print('batch {}'.format(batch_count))
            print('  minibatch loss: {}'.format(sess.run(total_loss, fd)))
            print('  minibatch clustering accurracy: {}'.format(a))
            for i,(e_in, dt_pred) in enumerate(zip(
                fd[encoder_inputs].T, # [max-time,batch_size] -> [batch_size,max-time]
                sess.run(decoder_prediction_train, fd).T
            )):
                print('  sample {}:'.format(i+1))
#                 print('    enc input           > {}'.format([w for w in to_sent(e_in) if w!='PAD']))
#                 print('    dec train predicted > {}'.format([w for w in to_sent(dt_pred) if w!='PAD']))
                print('    enc input           > {}'.format(to_sent(e_in)))
                print('    dec train predicted > {}'.format(to_sent(dt_pred)))
                if i>=2:
                    break
            print('\n')
except KeyboardInterrupt:
    print('training interrupted')
# Out:
# Epoch 1
#
#
# batch 100
#   minibatch loss: 1.5360682010650635
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['train', 'bike', 'bus', 'PAD']
#     dec train predicted > ['mouse', 'bike', 'train', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['mouse', 'car', 'deer', 'pig']
#     dec train predicted > ['car', 'cat', 'cat', 'dog', 'EOS']
#   sample 3:
#     enc input           > ['cat', 'mouse', 'bus', 'deer']
#     dec train predicted > ['car', 'mouse', 'car', 'pig', 'EOS']
#
#
# Epoch 2
#
#
# batch 200
#   minibatch loss: 1.548039197921753
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['cat', 'pig', 'pig', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['car', 'bike', 'motorcycle', 'PAD']
#     dec train predicted > ['mouse', 'bus', 'bus', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['car', 'motorcycle', 'motorcycle', 'PAD']
#     dec train predicted > ['mouse', 'bus', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 3
#
#
# batch 300
#   minibatch loss: 1.5566905736923218
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['dog', 'mouse', 'car', 'pig']
#     dec train predicted > ['car', 'deer', 'car', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['bike', 'car', 'cat', 'bike']
#     dec train predicted > ['car', 'dog', 'dog', 'car', 'EOS']
#   sample 3:
#     enc input           > ['bike', 'bike', 'deer', 'bus']
#     dec train predicted > ['car', 'dog', 'dog', 'train', 'EOS']
#
#
# Epoch 4
#
#
# batch 400
#   minibatch loss: 1.5365395545959473
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['mouse', 'deer', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'cat', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['motorcycle', 'train', 'bus', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['mouse', 'train', 'train', 'motorcycle']
#     dec train predicted > ['car', 'train', 'deer', 'train', 'EOS']
#
#
# Epoch 5
#
#
# batch 500
#   minibatch loss: 1.5416457653045654
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['dog', 'cat', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['car', 'car', 'train', 'PAD']
#     dec train predicted > ['mouse', 'bike', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['car', 'bike', 'pig', 'train']
#     dec train predicted > ['car', 'pig', 'dog', 'train', 'EOS']
#
#
# Epoch 6
#
#
# batch 600
#   minibatch loss: 1.54433012008667
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['cat', 'deer', 'deer', 'bus']
#     dec train predicted > ['car', 'mouse', 'deer', 'bus', 'EOS']
#   sample 2:
#     enc input           > ['deer', 'train', 'bus', 'motorcycle']
#     dec train predicted > ['car', 'deer', 'deer', 'motorcycle', 'EOS']
#   sample 3:
#     enc input           > ['deer', 'bike', 'bus', 'train']
#     dec train predicted > ['car', 'deer', 'cat', 'motorcycle', 'EOS']
#
#
# Epoch 7
#
#
# batch 700
#   minibatch loss: 1.5400859117507935
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['deer', 'cat', 'deer', 'motorcycle']
#     dec train predicted > ['car', 'train', 'car', 'bus', 'EOS']
#   sample 2:
#     enc input           > ['bike', 'bus', 'train', 'PAD']
#     dec train predicted > ['mouse', 'train', 'train', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['deer', 'car', 'pig', 'deer']
#     dec train predicted > ['car', 'train', 'car', 'deer', 'EOS']
#
#
# Epoch 8
#
#
# batch 800
#   minibatch loss: 1.53834068775177
#   minibatch clustering accurracy: 0.57
#   sample 1:
#     enc input           > ['pig', 'mouse', 'cat', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['pig', 'mouse', 'cat', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['pig', 'cat', 'pig', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#
#
# Epoch 9
#
#
# batch 900
#   minibatch loss: 1.5255306959152222
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['pig', 'mouse', 'deer', 'bus']
#     dec train predicted > ['bus', 'deer', 'bus', 'bus', 'EOS']
#   sample 2:
#     enc input           > ['motorcycle', 'car', 'car', 'PAD']
#     dec train predicted > ['train', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['car', 'deer', 'pig', 'cat']
#     dec train predicted > ['bus', 'motorcycle', 'bus', 'deer', 'EOS']
#
#
# Epoch 10
#
#
# batch 1000
#   minibatch loss: 1.56631600856781
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['dog', 'pig', 'dog', 'PAD']
#     dec train predicted > ['train', 'deer', 'dog', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bus', 'train', 'car', 'PAD']
#     dec train predicted > ['train', 'bus', 'bus', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['car', 'motorcycle', 'motorcycle', 'PAD']
#     dec train predicted > ['train', 'car', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 11
#
#
# batch 1100
#   minibatch loss: 1.5157551765441895
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['train', 'deer', 'car', 'bus']
#     dec train predicted > ['car', 'pig', 'bus', 'train', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'pig', 'dog', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['deer', 'pig', 'bus', 'dog']
#     dec train predicted > ['car', 'train', 'deer', 'pig', 'EOS']
#
#
# Epoch 12
#
#
# batch 1200
#   minibatch loss: 1.533569097518921
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['deer', 'dog', 'dog', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['pig', 'mouse', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'dog', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['dog', 'deer', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'dog', 'EOS', 'PAD']
#
#
# Epoch 13
#
#
# batch 1300
#   minibatch loss: 1.5353559255599976
#   minibatch clustering accurracy: 0.58
#   sample 1:
#     enc input           > ['cat', 'pig', 'deer', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['train', 'bus', 'motorcycle', 'PAD']
#     dec train predicted > ['mouse', 'bike', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['mouse', 'motorcycle', 'cat', 'deer']
#     dec train predicted > ['car', 'bike', 'motorcycle', 'cat', 'EOS']
#
#
# Epoch 14
#
#
# batch 1400
#   minibatch loss: 1.536065697669983
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['pig', 'mouse', 'deer', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'mouse', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['mouse', 'deer', 'dog', 'bike']
#     dec train predicted > ['car', 'train', 'bus', 'bus', 'EOS']
#   sample 3:
#     enc input           > ['motorcycle', 'bike', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 15
#
#
# batch 1500
#   minibatch loss: 1.541248083114624
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['bus', 'bus', 'motorcycle', 'PAD']
#     dec train predicted > ['mouse', 'bus', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['cat', 'car', 'pig', 'deer']
#     dec train predicted > ['bus', 'mouse', 'cat', 'pig', 'EOS']
#   sample 3:
#     enc input           > ['motorcycle', 'bike', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 16
#
#
# batch 1600
#   minibatch loss: 1.5171799659729004
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['dog', 'pig', 'train', 'dog']
#     dec train predicted > ['car', 'deer', 'car', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'deer', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['train', 'motorcycle', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'bike', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 17
# batch 1700
#   minibatch loss: 1.5447883605957031
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['pig', 'dog', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'dog', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['motorcycle', 'car', 'cat', 'motorcycle']
#     dec train predicted > ['deer', 'motorcycle', 'bike', 'car', 'EOS']
#   sample 3:
#     enc input           > ['dog', 'deer', 'bus', 'dog']
#     dec train predicted > ['deer', 'deer', 'bus', 'pig', 'EOS']
#
#
# Epoch 18
#
#
# batch 1800
#   minibatch loss: 1.5303622484207153
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['motorcycle', 'bike', 'train', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'bus', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['mouse', 'dog', 'deer', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'dog', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['deer', 'deer', 'pig', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'deer', 'EOS', 'PAD']
#
#
# Epoch 19
#
#
# batch 1900
#   minibatch loss: 1.5199631452560425
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['bus', 'motorcycle', 'deer', 'bus']
#     dec train predicted > ['car', 'bus', 'motorcycle', 'car', 'EOS']
#   sample 2:
#     enc input           > ['mouse', 'mouse', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['deer', 'mouse', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#
#
# Epoch 20
#
#
# batch 2000
#   minibatch loss: 1.4935269355773926
#   minibatch clustering accurracy: 0.62
#   sample 1:
#     enc input           > ['train', 'car', 'motorcycle', 'cat']
#     dec train predicted > ['bus', 'pig', 'car', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['bus', 'dog', 'deer', 'pig']
#     dec train predicted > ['bus', 'pig', 'pig', 'pig', 'EOS']
#   sample 3:
#     enc input           > ['dog', 'bike', 'bus', 'bike']
#     dec train predicted > ['bus', 'deer', 'dog', 'motorcycle', 'EOS']
#
#
# Epoch 21
#
#
# batch 2100
#   minibatch loss: 1.5391943454742432
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['deer', 'pig', 'train', 'mouse']
#     dec train predicted > ['bus', 'train', 'deer', 'pig', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'cat', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['car', 'car', 'bus', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 22
#
#
# batch 2200
#   minibatch loss: 1.5577428340911865
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['deer', 'cat', 'motorcycle', 'mouse']
#     dec train predicted > ['car', 'train', 'car', 'cat', 'EOS']
#   sample 2:
#     enc input           > ['train', 'bus', 'motorcycle', 'PAD']
#     dec train predicted > ['train', 'bike', 'car', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['mouse', 'car', 'deer', 'deer']
#     dec train predicted > ['car', 'train', 'car', 'cat', 'EOS']
#
#
# Epoch 23
#
#
# batch 2300
#   minibatch loss: 1.526695966720581
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['bike', 'bike', 'mouse', 'train']
#     dec train predicted > ['car', 'cat', 'dog', 'train', 'EOS']
#   sample 2:
#     enc input           > ['motorcycle', 'mouse', 'motorcycle', 'bike']
#     dec train predicted > ['car', 'motorcycle', 'car', 'bike', 'EOS']
#   sample 3:
#     enc input           > ['cat', 'train', 'motorcycle', 'car']
#     dec train predicted > ['car', 'mouse', 'mouse', 'bike', 'EOS']
#
#
# Epoch 24
#
#
# batch 2400
#   minibatch loss: 1.5110992193222046
#   minibatch clustering accurracy: 0.63
#   sample 1:
#     enc input           > ['bus', 'pig', 'dog', 'cat']
#     dec train predicted > ['deer', 'pig', 'pig', 'pig', 'EOS']
#   sample 2:
#     enc input           > ['motorcycle', 'deer', 'train', 'train']
#     dec train predicted > ['deer', 'pig', 'deer', 'train', 'EOS']
#   sample 3:
#     enc input           > ['pig', 'dog', 'car', 'mouse']
#     dec train predicted > ['deer', 'cat', 'cat', 'cat', 'EOS']
#
#
# Epoch 25
#
#
# batch 2500
#   minibatch loss: 1.5315755605697632
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['dog', 'pig', 'motorcycle', 'deer']
#     dec train predicted > ['deer', 'cat', 'cat', 'cat', 'EOS']
#   sample 2:
#     enc input           > ['cat', 'deer', 'dog', 'PAD']
#     dec train predicted > ['mouse', 'cat', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['train', 'bike', 'cat', 'train']
#     dec train predicted > ['deer', 'pig', 'bike', 'car', 'EOS']
#
#
# Epoch 26
#
#
# batch 2600
#   minibatch loss: 1.5307517051696777
#   minibatch clustering accurracy: 0.5
#   sample 1:
#     enc input           > ['deer', 'pig', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'deer', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['car', 'bus', 'car', 'deer']
#     dec train predicted > ['car', 'motorcycle', 'car', 'dog', 'EOS']
#   sample 3:
#     enc input           > ['bus', 'bike', 'motorcycle', 'deer']
#     dec train predicted > ['car', 'pig', 'dog', 'dog', 'EOS']
#
#
# Epoch 27
#
#
# batch 2700
#   minibatch loss: 1.5493531227111816
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['dog', 'bus', 'pig', 'pig']
#     dec train predicted > ['bus', 'deer', 'pig', 'pig', 'EOS']
#   sample 2:
#     enc input           > ['mouse', 'cat', 'pig', 'motorcycle']
#     dec train predicted > ['bus', 'cat', 'car', 'bus', 'EOS']
#   sample 3:
#     enc input           > ['car', 'bus', 'bike', 'PAD']
#     dec train predicted > ['train', 'car', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 28
#
#
# batch 2800
#   minibatch loss: 1.514309287071228
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['dog', 'train', 'train', 'car']
#     dec train predicted > ['bus', 'deer', 'motorcycle', 'train', 'EOS']
#   sample 2:
#     enc input           > ['dog', 'dog', 'cat', 'PAD']
#     dec train predicted > ['train', 'deer', 'pig', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['pig', 'pig', 'pig', 'PAD']
#     dec train predicted > ['train', 'deer', 'dog', 'EOS', 'PAD']
#
#
# Epoch 29
#
#
# batch 2900
#   minibatch loss: 1.4756559133529663
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['mouse', 'dog', 'pig', 'PAD']
#     dec train predicted > ['train', 'mouse', 'pig', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['mouse', 'dog', 'dog', 'car']
#     dec train predicted > ['car', 'mouse', 'car', 'car', 'EOS']
#   sample 3:
#     enc input           > ['train', 'car', 'car', 'PAD']
#     dec train predicted > ['train', 'bike', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 30
#
#
# batch 3000
#   minibatch loss: 1.52885901927948
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['bike', 'bike', 'car', 'dog']
#     dec train predicted > ['deer', 'cat', 'dog', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['deer', 'deer', 'deer', 'bike']
#     dec train predicted > ['deer', 'train', 'deer', 'bus', 'EOS']
#   sample 3:
#     enc input           > ['motorcycle', 'bus', 'train', 'pig']
#     dec train predicted > ['deer', 'motorcycle', 'bike', 'dog', 'EOS']
#
#
# Epoch 31
#
#
# batch 3100
#   minibatch loss: 1.4869880676269531
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['pig', 'pig', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'dog', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['cat', 'cat', 'pig', 'PAD']
#     dec train predicted > ['mouse', 'cat', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['train', 'motorcycle', 'bus', 'PAD']
#     dec train predicted > ['mouse', 'car', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 32
#
#
# batch 3200
#   minibatch loss: 1.509899616241455
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['cat', 'mouse', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'cat', 'cat', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['train', 'bike', 'deer', 'bus']
#     dec train predicted > ['bus', 'pig', 'car', 'car', 'EOS']
#   sample 3:
#     enc input           > ['train', 'bus', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'bus', 'car', 'EOS', 'PAD']
#
#
# Epoch 33
# batch 3300
#   minibatch loss: 1.5562635660171509
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['train', 'cat', 'bus', 'train']
#     dec train predicted > ['deer', 'pig', 'pig', 'train', 'EOS']
#   sample 2:
#     enc input           > ['cat', 'pig', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'pig', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['mouse', 'pig', 'mouse', 'train']
#     dec train predicted > ['deer', 'mouse', 'deer', 'train', 'EOS']
#
#
# Epoch 34
#
#
# batch 3400
#   minibatch loss: 1.5397142171859741
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['train', 'dog', 'bike', 'train']
#     dec train predicted > ['car', 'motorcycle', 'motorcycle', 'train', 'EOS']
#   sample 2:
#     enc input           > ['deer', 'mouse', 'deer', 'PAD']
#     dec train predicted > ['train', 'deer', 'mouse', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['train', 'bike', 'cat', 'car']
#     dec train predicted > ['car', 'motorcycle', 'bike', 'train', 'EOS']
#
#
# Epoch 35
#
#
# batch 3500
#   minibatch loss: 1.5172957181930542
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['cat', 'bike', 'cat', 'pig']
#     dec train predicted > ['deer', 'mouse', 'mouse', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['cat', 'mouse', 'pig', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'mouse', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['deer', 'motorcycle', 'pig', 'dog']
#     dec train predicted > ['deer', 'deer', 'deer', 'dog', 'EOS']
#
#
# Epoch 36
#
#
# batch 3600
#   minibatch loss: 1.5336356163024902
#   minibatch clustering accurracy: 0.5
#   sample 1:
#     enc input           > ['dog', 'pig', 'dog', 'bike']
#     dec train predicted > ['bus', 'deer', 'deer', 'car', 'EOS']
#   sample 2:
#     enc input           > ['bus', 'motorcycle', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'bus', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['motorcycle', 'deer', 'deer', 'pig']
#     dec train predicted > ['bus', 'motorcycle', 'bus', 'deer', 'EOS']
#
#
# Epoch 37
#
#
# batch 3700
#   minibatch loss: 1.4963603019714355
#   minibatch clustering accurracy: 0.6
#   sample 1:
#     enc input           > ['bike', 'train', 'car', 'PAD']
#     dec train predicted > ['mouse', 'train', 'car', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bus', 'train', 'train', 'PAD']
#     dec train predicted > ['mouse', 'bus', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['car', 'motorcycle', 'car', 'PAD']
#     dec train predicted > ['mouse', 'car', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 38
#
#
# batch 3800
#   minibatch loss: 1.5062274932861328
#   minibatch clustering accurracy: 0.59
#   sample 1:
#     enc input           > ['bus', 'mouse', 'train', 'train']
#     dec train predicted > ['deer', 'bus', 'pig', 'train', 'EOS']
#   sample 2:
#     enc input           > ['mouse', 'deer', 'deer', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['train', 'bike', 'car', 'PAD']
#     dec train predicted > ['mouse', 'bike', 'bus', 'EOS', 'PAD']
#
#
# Epoch 39
#
#
# batch 3900
#   minibatch loss: 1.5267479419708252
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['dog', 'cat', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bus', 'cat', 'deer', 'cat']
#     dec train predicted > ['deer', 'pig', 'pig', 'pig', 'EOS']
#   sample 3:
#     enc input           > ['cat', 'car', 'bike', 'car']
#     dec train predicted > ['deer', 'mouse', 'car', 'train', 'EOS']
#
#
# Epoch 40
#
#
# batch 4000
#   minibatch loss: 1.5263832807540894
#   minibatch clustering accurracy: 0.58
#   sample 1:
#     enc input           > ['dog', 'train', 'motorcycle', 'train']
#     dec train predicted > ['bus', 'deer', 'car', 'bike', 'EOS']
#   sample 2:
#     enc input           > ['train', 'car', 'motorcycle', 'PAD']
#     dec train predicted > ['train', 'bike', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['deer', 'dog', 'train', 'dog']
#     dec train predicted > ['bus', 'motorcycle', 'bus', 'pig', 'EOS']
#
#
# Epoch 41
#
#
# batch 4100
#   minibatch loss: 1.524924635887146
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['bus', 'bus', 'car', 'PAD']
#     dec train predicted > ['mouse', 'bus', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['motorcycle', 'pig', 'train', 'car']
#     dec train predicted > ['deer', 'pig', 'deer', 'bike', 'EOS']
#   sample 3:
#     enc input           > ['cat', 'pig', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'cat', 'cat', 'EOS', 'PAD']
#
#
# Epoch 42
#
#
# batch 4200
#   minibatch loss: 1.5127592086791992
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['pig', 'cat', 'dog', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['car', 'bike', 'bus', 'PAD']
#     dec train predicted > ['train', 'bike', 'bus', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['bus', 'car', 'pig', 'bike']
#     dec train predicted > ['bus', 'bus', 'bike', 'car', 'EOS']
#
#
# Epoch 43
#
#
# batch 4300
#   minibatch loss: 1.5514317750930786
#   minibatch clustering accurracy: 0.6
#   sample 1:
#     enc input           > ['bus', 'cat', 'dog', 'cat']
#     dec train predicted > ['bus', 'bus', 'bus', 'pig', 'EOS']
#   sample 2:
#     enc input           > ['cat', 'pig', 'mouse', 'motorcycle']
#     dec train predicted > ['bus', 'car', 'deer', 'bus', 'EOS']
#   sample 3:
#     enc input           > ['car', 'deer', 'mouse', 'deer']
#     dec train predicted > ['bus', 'car', 'bus', 'deer', 'EOS']
#
#
# Epoch 44
#
#
# batch 4400
#   minibatch loss: 1.5101406574249268
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['pig', 'car', 'bus', 'bus']
#     dec train predicted > ['car', 'cat', 'car', 'motorcycle', 'EOS']
#   sample 2:
#     enc input           > ['car', 'train', 'deer', 'car']
#     dec train predicted > ['car', 'motorcycle', 'bike', 'car', 'EOS']
#   sample 3:
#     enc input           > ['pig', 'mouse', 'mouse', 'PAD']
#     dec train predicted > ['train', 'deer', 'mouse', 'EOS', 'PAD']
#
#
# Epoch 45
#
#
# batch 4500
#   minibatch loss: 1.4907622337341309
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['train', 'pig', 'cat', 'cat']
#     dec train predicted > ['deer', 'pig', 'car', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['train', 'bus', 'motorcycle', 'PAD']
#     dec train predicted > ['mouse', 'car', 'car', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['cat', 'bike', 'bike', 'bike']
#     dec train predicted > ['deer', 'mouse', 'car', 'train', 'EOS']
#
#
# Epoch 46
#
#
# batch 4600
#   minibatch loss: 1.5052286386489868
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['motorcycle', 'mouse', 'motorcycle', 'bus']
#     dec train predicted > ['car', 'motorcycle', 'bike', 'bike', 'EOS']
#   sample 2:
#     enc input           > ['mouse', 'mouse', 'pig', 'PAD']
#     dec train predicted > ['train', 'mouse', 'mouse', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['bike', 'motorcycle', 'bus', 'PAD']
#     dec train predicted > ['train', 'train', 'bike', 'EOS', 'PAD']
#
#
# Epoch 47
#
#
# batch 4700
#   minibatch loss: 1.503459095954895
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['train', 'dog', 'bike', 'bus']
#     dec train predicted > ['deer', 'pig', 'pig', 'train', 'EOS']
#   sample 2:
#     enc input           > ['car', 'bus', 'car', 'PAD']
#     dec train predicted > ['mouse', 'car', 'bus', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['motorcycle', 'deer', 'train', 'car']
#     dec train predicted > ['deer', 'motorcycle', 'deer', 'train', 'EOS']
#
#
# Epoch 48
#
#
# batch 4800
#   minibatch loss: 1.4887324571609497
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['deer', 'dog', 'cat', 'car']
#     dec train predicted > ['bus', 'train', 'deer', 'car', 'EOS']
#   sample 2:
#     enc input           > ['dog', 'deer', 'deer', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['motorcycle', 'motorcycle', 'bus', 'PAD']
#     dec train predicted > ['train', 'train', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 49
# batch 4900
#   minibatch loss: 1.4847418069839478
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['bike', 'pig', 'deer', 'mouse']
#     dec train predicted > ['deer', 'cat', 'pig', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['deer', 'mouse', 'deer', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['mouse', 'cat', 'bike', 'dog']
#     dec train predicted > ['deer', 'bike', 'car', 'dog', 'EOS']
#
#
# Epoch 50
#
#
# batch 5000
#   minibatch loss: 1.491468906402588
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['dog', 'cat', 'dog', 'bike']
#     dec train predicted > ['car', 'deer', 'car', 'car', 'EOS']
#   sample 2:
#     enc input           > ['cat', 'cat', 'pig', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['dog', 'car', 'car', 'car']
#     dec train predicted > ['car', 'deer', 'car', 'motorcycle', 'EOS']
#
#
# Epoch 51
#
#
# batch 5100
#   minibatch loss: 1.5431700944900513
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['dog', 'bike', 'cat', 'deer']
#     dec train predicted > ['deer', 'cat', 'car', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['car', 'car', 'bike', 'mouse']
#     dec train predicted > ['deer', 'car', 'car', 'dog', 'EOS']
#   sample 3:
#     enc input           > ['cat', 'cat', 'deer', 'train']
#     dec train predicted > ['deer', 'car', 'car', 'car', 'EOS']
#
#
# Epoch 52
#
#
# batch 5200
#   minibatch loss: 1.5496113300323486
#   minibatch clustering accurracy: 0.57
#   sample 1:
#     enc input           > ['motorcycle', 'bus', 'train', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['train', 'bus', 'motorcycle', 'PAD']
#     dec train predicted > ['mouse', 'bike', 'car', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['pig', 'deer', 'train', 'mouse']
#     dec train predicted > ['deer', 'train', 'deer', 'cat', 'EOS']
#
#
# Epoch 53
#
#
# batch 5300
#   minibatch loss: 1.4881491661071777
#   minibatch clustering accurracy: 0.63
#   sample 1:
#     enc input           > ['dog', 'pig', 'deer', 'bike']
#     dec train predicted > ['bus', 'cat', 'bus', 'motorcycle', 'EOS']
#   sample 2:
#     enc input           > ['cat', 'cat', 'cat', 'train']
#     dec train predicted > ['bus', 'car', 'car', 'car', 'EOS']
#   sample 3:
#     enc input           > ['dog', 'deer', 'pig', 'car']
#     dec train predicted > ['bus', 'cat', 'bus', 'motorcycle', 'EOS']
#
#
# Epoch 54
#
#
# batch 5400
#   minibatch loss: 1.5060197114944458
#   minibatch clustering accurracy: 0.57
#   sample 1:
#     enc input           > ['motorcycle', 'car', 'car', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['cat', 'cat', 'cat', 'train']
#     dec train predicted > ['deer', 'car', 'car', 'car', 'EOS']
#   sample 3:
#     enc input           > ['car', 'car', 'train', 'PAD']
#     dec train predicted > ['mouse', 'car', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 55
#
#
# batch 5500
#   minibatch loss: 1.479551076889038
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['deer', 'car', 'bus', 'motorcycle']
#     dec train predicted > ['bus', 'train', 'car', 'motorcycle', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'deer', 'motorcycle', 'dog']
#     dec train predicted > ['bus', 'train', 'deer', 'cat', 'EOS']
#   sample 3:
#     enc input           > ['train', 'bus', 'bus', 'PAD']
#     dec train predicted > ['train', 'train', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 56
#
#
# batch 5600
#   minibatch loss: 1.502353310585022
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['bus', 'motorcycle', 'motorcycle', 'PAD']
#     dec train predicted > ['train', 'bus', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bike', 'train', 'bus', 'PAD']
#     dec train predicted > ['train', 'train', 'car', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['mouse', 'mouse', 'pig', 'PAD']
#     dec train predicted > ['train', 'mouse', 'cat', 'EOS', 'PAD']
#
#
# Epoch 57
#
#
# batch 5700
#   minibatch loss: 1.4889785051345825
#   minibatch clustering accurracy: 0.58
#   sample 1:
#     enc input           > ['car', 'mouse', 'cat', 'deer']
#     dec train predicted > ['bus', 'motorcycle', 'deer', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['car', 'bike', 'bus', 'PAD']
#     dec train predicted > ['train', 'car', 'bus', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['cat', 'deer', 'bus', 'pig']
#     dec train predicted > ['bus', 'car', 'deer', 'pig', 'EOS']
#
#
# Epoch 58
#
#
# batch 5800
#   minibatch loss: 1.4850130081176758
#   minibatch clustering accurracy: 0.5
#   sample 1:
#     enc input           > ['car', 'bus', 'motorcycle', 'cat']
#     dec train predicted > ['bus', 'car', 'bus', 'cat', 'EOS']
#   sample 2:
#     enc input           > ['deer', 'mouse', 'pig', 'train']
#     dec train predicted > ['bus', 'train', 'bus', 'bus', 'EOS']
#   sample 3:
#     enc input           > ['mouse', 'deer', 'cat', 'PAD']
#     dec train predicted > ['train', 'mouse', 'cat', 'EOS', 'PAD']
#
#
# Epoch 59
#
#
# batch 5900
#   minibatch loss: 1.492276668548584
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['motorcycle', 'motorcycle', 'motorcycle', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['car', 'motorcycle', 'train', 'PAD']
#     dec train predicted > ['mouse', 'car', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['pig', 'dog', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#
#
# Epoch 60
#
#
# batch 6000
#   minibatch loss: 1.494752287864685
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['train', 'train', 'bike', 'deer']
#     dec train predicted > ['bus', 'cat', 'bike', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['car', 'bike', 'bike', 'PAD']
#     dec train predicted > ['train', 'motorcycle', 'bus', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['cat', 'car', 'car', 'car']
#     dec train predicted > ['bus', 'car', 'car', 'motorcycle', 'EOS']
#
#
# Epoch 61
#
#
# batch 6100
#   minibatch loss: 1.4980477094650269
#   minibatch clustering accurracy: 0.57
#   sample 1:
#     enc input           > ['car', 'car', 'train', 'PAD']
#     dec train predicted > ['mouse', 'car', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bike', 'bus', 'dog', 'train']
#     dec train predicted > ['bus', 'dog', 'dog', 'train', 'EOS']
#   sample 3:
#     enc input           > ['dog', 'cat', 'dog', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#
#
# Epoch 62
#
#
# batch 6200
#   minibatch loss: 1.4807567596435547
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['car', 'deer', 'pig', 'dog']
#     dec train predicted > ['deer', 'car', 'bus', 'deer', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'pig', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['car', 'motorcycle', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'car', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 63
#
#
# batch 6300
#   minibatch loss: 1.4784793853759766
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['dog', 'mouse', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['mouse', 'cat', 'dog', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['pig', 'mouse', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'mouse', 'EOS', 'PAD']
#
#
# Epoch 64
#
#
# batch 6400
#   minibatch loss: 1.497120976448059
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['bike', 'car', 'bike', 'PAD']
#     dec train predicted > ['train', 'train', 'bus', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bus', 'motorcycle', 'motorcycle', 'PAD']
#     dec train predicted > ['train', 'train', 'motorcycle', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['car', 'car', 'dog', 'train']
#     dec train predicted > ['bus', 'motorcycle', 'bike', 'car', 'EOS']
#
#
# Epoch 65
# batch 6500
#   minibatch loss: 1.4904175996780396
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['train', 'mouse', 'bus', 'motorcycle']
#     dec train predicted > ['deer', 'bike', 'bus', 'bike', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'deer', 'deer', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['mouse', 'cat', 'dog', 'PAD']
#     dec train predicted > ['train', 'mouse', 'cat', 'EOS', 'PAD']
#
#
# Epoch 66
#
#
# batch 6600
#   minibatch loss: 1.4543472528457642
#   minibatch clustering accurracy: 0.58
#   sample 1:
#     enc input           > ['train', 'car', 'train', 'PAD']
#     dec train predicted > ['mouse', 'train', 'bus', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bus', 'car', 'train', 'PAD']
#     dec train predicted > ['mouse', 'train', 'bus', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['bike', 'bus', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'train', 'train', 'EOS', 'PAD']
#
#
# Epoch 67
#
#
# batch 6700
#   minibatch loss: 1.5024821758270264
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['dog', 'mouse', 'bike', 'cat']
#     dec train predicted > ['deer', 'cat', 'bus', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['mouse', 'deer', 'mouse', 'bike']
#     dec train predicted > ['deer', 'cat', 'deer', 'bus', 'EOS']
#   sample 3:
#     enc input           > ['dog', 'deer', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'dog', 'EOS', 'PAD']
#
#
# Epoch 68
#
#
# batch 6800
#   minibatch loss: 1.4969244003295898
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['pig', 'mouse', 'deer', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['mouse', 'train', 'cat', 'dog']
#     dec train predicted > ['deer', 'bike', 'mouse', 'dog', 'EOS']
#   sample 3:
#     enc input           > ['dog', 'train', 'cat', 'cat']
#     dec train predicted > ['deer', 'deer', 'mouse', 'dog', 'EOS']
#
#
# Epoch 69
#
#
# batch 6900
#   minibatch loss: 1.461390495300293
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['motorcycle', 'train', 'train', 'PAD']
#     dec train predicted > ['train', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bike', 'motorcycle', 'car', 'PAD']
#     dec train predicted > ['train', 'train', 'bike', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['pig', 'cat', 'dog', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#
#
# Epoch 70
#
#
# batch 7000
#   minibatch loss: 1.5018508434295654
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['car', 'motorcycle', 'car', 'PAD']
#     dec train predicted > ['train', 'car', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['deer', 'mouse', 'dog', 'PAD']
#     dec train predicted > ['train', 'deer', 'deer', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['train', 'car', 'bike', 'PAD']
#     dec train predicted > ['train', 'car', 'car', 'EOS', 'PAD']
#
#
# Epoch 71
#
#
# batch 7100
#   minibatch loss: 1.5032016038894653
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['cat', 'pig', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'cat', 'deer', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['mouse', 'bus', 'pig', 'mouse']
#     dec train predicted > ['deer', 'bike', 'cat', 'mouse', 'EOS']
#   sample 3:
#     enc input           > ['cat', 'cat', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'cat', 'cat', 'EOS', 'PAD']
#
#
# Epoch 72
#
#
# batch 7200
#   minibatch loss: 1.4793318510055542
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['dog', 'pig', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['deer', 'car', 'bus', 'motorcycle']
#     dec train predicted > ['deer', 'deer', 'deer', 'motorcycle', 'EOS']
#   sample 3:
#     enc input           > ['motorcycle', 'car', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#
#
# Epoch 73
#
#
# batch 7300
#   minibatch loss: 1.5342912673950195
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['train', 'bus', 'dog', 'car']
#     dec train predicted > ['deer', 'pig', 'pig', 'train', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'bus', 'mouse', 'mouse']
#     dec train predicted > ['deer', 'train', 'dog', 'dog', 'EOS']
#   sample 3:
#     enc input           > ['deer', 'pig', 'mouse', 'bike']
#     dec train predicted > ['deer', 'bus', 'deer', 'bus', 'EOS']
#
#
# Epoch 74
#
#
# batch 7400
#   minibatch loss: 1.4760721921920776
#   minibatch clustering accurracy: 0.61
#   sample 1:
#     enc input           > ['cat', 'deer', 'cat', 'PAD']
#     dec train predicted > ['train', 'mouse', 'deer', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['dog', 'train', 'motorcycle', 'train']
#     dec train predicted > ['bus', 'bike', 'car', 'bike', 'EOS']
#   sample 3:
#     enc input           > ['dog', 'deer', 'train', 'pig']
#     dec train predicted > ['bus', 'bike', 'bus', 'dog', 'EOS']
#
#
# Epoch 75
#
#
# batch 7500
#   minibatch loss: 1.4778167009353638
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['motorcycle', 'bike', 'train', 'PAD']
#     dec train predicted > ['mouse', 'train', 'train', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['train', 'motorcycle', 'bus', 'pig']
#     dec train predicted > ['deer', 'pig', 'bike', 'cat', 'EOS']
#   sample 3:
#     enc input           > ['deer', 'motorcycle', 'bike', 'motorcycle']
#     dec train predicted > ['deer', 'deer', 'deer', 'train', 'EOS']
#
#
# Epoch 76
#
#
# batch 7600
#   minibatch loss: 1.4738335609436035
#   minibatch clustering accurracy: 0.5
#   sample 1:
#     enc input           > ['cat', 'pig', 'motorcycle', 'cat']
#     dec train predicted > ['bus', 'car', 'cat', 'cat', 'EOS']
#   sample 2:
#     enc input           > ['motorcycle', 'deer', 'bike', 'bus']
#     dec train predicted > ['bus', 'motorcycle', 'motorcycle', 'train', 'EOS']
#   sample 3:
#     enc input           > ['train', 'car', 'motorcycle', 'pig']
#     dec train predicted > ['bus', 'pig', 'bike', 'cat', 'EOS']
#
#
# Epoch 77
#
#
# batch 7700
#   minibatch loss: 1.4895365238189697
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['deer', 'deer', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'deer', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['dog', 'pig', 'deer', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['dog', 'deer', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#
#
# Epoch 78
#
#
# batch 7800
#   minibatch loss: 1.4909262657165527
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['car', 'car', 'motorcycle', 'PAD']
#     dec train predicted > ['train', 'car', 'bus', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['deer', 'bus', 'mouse', 'cat']
#     dec train predicted > ['bus', 'bus', 'pig', 'pig', 'EOS']
#   sample 3:
#     enc input           > ['bike', 'bike', 'bus', 'PAD']
#     dec train predicted > ['train', 'train', 'train', 'EOS', 'PAD']
#
#
# Epoch 79
#
#
# batch 7900
#   minibatch loss: 1.4673606157302856
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['pig', 'dog', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['pig', 'deer', 'mouse', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'deer', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['dog', 'pig', 'dog', 'train']
#     dec train predicted > ['deer', 'cat', 'cat', 'car', 'EOS']
#
#
# Epoch 80
#
#
# batch 8000
#   minibatch loss: 1.4902416467666626
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['car', 'pig', 'cat', 'dog']
#     dec train predicted > ['deer', 'car', 'deer', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['dog', 'mouse', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'mouse', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['deer', 'pig', 'dog', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#
#
# Epoch 81
# batch 8100
#   minibatch loss: 1.4382965564727783
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['car', 'train', 'train', 'PAD']
#     dec train predicted > ['mouse', 'car', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['motorcycle', 'bus', 'train', 'mouse']
#     dec train predicted > ['deer', 'motorcycle', 'motorcycle', 'dog', 'EOS']
#   sample 3:
#     enc input           > ['mouse', 'pig', 'cat', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'mouse', 'EOS', 'PAD']
#
#
# Epoch 82
#
#
# batch 8200
#   minibatch loss: 1.4990031719207764
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['dog', 'dog', 'deer', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['bike', 'deer', 'bus', 'car']
#     dec train predicted > ['deer', 'cat', 'bus', 'bike', 'EOS']
#   sample 3:
#     enc input           > ['bike', 'bike', 'bike', 'PAD']
#     dec train predicted > ['mouse', 'train', 'train', 'EOS', 'PAD']
#
#
# Epoch 83
#
#
# batch 8300
#   minibatch loss: 1.4598997831344604
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['bike', 'deer', 'train', 'bus']
#     dec train predicted > ['bus', 'cat', 'bus', 'train', 'EOS']
#   sample 2:
#     enc input           > ['bus', 'motorcycle', 'car', 'mouse']
#     dec train predicted > ['bus', 'bus', 'cat', 'cat', 'EOS']
#   sample 3:
#     enc input           > ['pig', 'train', 'train', 'train']
#     dec train predicted > ['bus', 'cat', 'dog', 'train', 'EOS']
#
#
# Epoch 84
#
#
# batch 8400
#   minibatch loss: 1.5113835334777832
#   minibatch clustering accurracy: 0.58
#   sample 1:
#     enc input           > ['mouse', 'bike', 'dog', 'cat']
#     dec train predicted > ['deer', 'bike', 'car', 'pig', 'EOS']
#   sample 2:
#     enc input           > ['deer', 'train', 'bus', 'train']
#     dec train predicted > ['deer', 'bus', 'bus', 'bike', 'EOS']
#   sample 3:
#     enc input           > ['dog', 'cat', 'pig', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#
#
# Epoch 85
#
#
# batch 8500
#   minibatch loss: 1.4857687950134277
#   minibatch clustering accurracy: 0.52
#   sample 1:
#     enc input           > ['motorcycle', 'mouse', 'train', 'bike']
#     dec train predicted > ['deer', 'motorcycle', 'motorcycle', 'bike', 'EOS']
#   sample 2:
#     enc input           > ['motorcycle', 'motorcycle', 'deer', 'bike']
#     dec train predicted > ['deer', 'motorcycle', 'motorcycle', 'car', 'EOS']
#   sample 3:
#     enc input           > ['bike', 'mouse', 'pig', 'mouse']
#     dec train predicted > ['deer', 'car', 'car', 'deer', 'EOS']
#
#
# Epoch 86
#
#
# batch 8600
#   minibatch loss: 1.5281662940979004
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['bike', 'bus', 'dog', 'train']
#     dec train predicted > ['deer', 'cat', 'pig', 'train', 'EOS']
#   sample 2:
#     enc input           > ['train', 'bike', 'car', 'PAD']
#     dec train predicted > ['mouse', 'train', 'train', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['motorcycle', 'car', 'car', 'mouse']
#     dec train predicted > ['deer', 'motorcycle', 'car', 'cat', 'EOS']
#
#
# Epoch 87
#
#
# batch 8700
#   minibatch loss: 1.4938756227493286
#   minibatch clustering accurracy: 0.58
#   sample 1:
#     enc input           > ['car', 'mouse', 'cat', 'deer']
#     dec train predicted > ['deer', 'car', 'deer', 'deer', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'dog', 'cat', 'bike']
#     dec train predicted > ['deer', 'deer', 'train', 'car', 'EOS']
#   sample 3:
#     enc input           > ['motorcycle', 'mouse', 'deer', 'pig']
#     dec train predicted > ['deer', 'motorcycle', 'motorcycle', 'deer', 'EOS']
#
#
# Epoch 88
#
#
# batch 8800
#   minibatch loss: 1.4690775871276855
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['cat', 'car', 'motorcycle', 'bus']
#     dec train predicted > ['bus', 'car', 'car', 'bike', 'EOS']
#   sample 2:
#     enc input           > ['bike', 'car', 'bus', 'PAD']
#     dec train predicted > ['train', 'train', 'car', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['bus', 'train', 'deer', 'bus']
#     dec train predicted > ['bus', 'pig', 'pig', 'car', 'EOS']
#
#
# Epoch 89
#
#
# batch 8900
#   minibatch loss: 1.484885573387146
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['mouse', 'mouse', 'dog', 'PAD']
#     dec train predicted > ['mouse', 'mouse', 'mouse', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['pig', 'cat', 'bus', 'pig']
#     dec train predicted > ['deer', 'cat', 'car', 'pig', 'EOS']
#   sample 3:
#     enc input           > ['bike', 'car', 'motorcycle', 'PAD']
#     dec train predicted > ['mouse', 'train', 'car', 'EOS', 'PAD']
#
#
# Epoch 90
#
#
# batch 9000
#   minibatch loss: 1.5209951400756836
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['bus', 'car', 'pig', 'motorcycle']
#     dec train predicted > ['deer', 'pig', 'dog', 'car', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'cat', 'pig', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['motorcycle', 'bus', 'deer', 'bike']
#     dec train predicted > ['deer', 'pig', 'dog', 'car', 'EOS']
#
#
# Epoch 91
#
#
# batch 9100
#   minibatch loss: 1.4954888820648193
#   minibatch clustering accurracy: 0.5
#   sample 1:
#     enc input           > ['deer', 'dog', 'bike', 'dog']
#     dec train predicted > ['deer', 'deer', 'deer', 'dog', 'EOS']
#   sample 2:
#     enc input           > ['train', 'mouse', 'motorcycle', 'car']
#     dec train predicted > ['deer', 'pig', 'bus', 'bike', 'EOS']
#   sample 3:
#     enc input           > ['bus', 'bike', 'motorcycle', 'dog']
#     dec train predicted > ['deer', 'pig', 'dog', 'dog', 'EOS']
#
#
# Epoch 92
#
#
# batch 9200
#   minibatch loss: 1.508578896522522
#   minibatch clustering accurracy: 0.51
#   sample 1:
#     enc input           > ['car', 'motorcycle', 'bus', 'cat']
#     dec train predicted > ['deer', 'car', 'cat', 'cat', 'EOS']
#   sample 2:
#     enc input           > ['car', 'pig', 'car', 'car']
#     dec train predicted > ['deer', 'car', 'deer', 'bike', 'EOS']
#   sample 3:
#     enc input           > ['pig', 'motorcycle', 'motorcycle', 'train']
#     dec train predicted > ['deer', 'cat', 'cat', 'bike', 'EOS']
#
#
# Epoch 93
#
#
# batch 9300
#   minibatch loss: 1.5131498575210571
#   minibatch clustering accurracy: 0.54
#   sample 1:
#     enc input           > ['deer', 'bus', 'train', 'bus']
#     dec train predicted > ['deer', 'deer', 'pig', 'train', 'EOS']
#   sample 2:
#     enc input           > ['cat', 'car', 'deer', 'deer']
#     dec train predicted > ['deer', 'car', 'car', 'cat', 'EOS']
#   sample 3:
#     enc input           > ['train', 'bike', 'car', 'PAD']
#     dec train predicted > ['mouse', 'car', 'train', 'EOS', 'PAD']
#
#
# Epoch 94
#
#
# batch 9400
#   minibatch loss: 1.447769045829773
#   minibatch clustering accurracy: 0.55
#   sample 1:
#     enc input           > ['car', 'train', 'bus', 'PAD']
#     dec train predicted > ['train', 'car', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['deer', 'cat', 'mouse', 'PAD']
#     dec train predicted > ['train', 'deer', 'cat', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['motorcycle', 'motorcycle', 'train', 'dog']
#     dec train predicted > ['deer', 'motorcycle', 'motorcycle', 'dog', 'EOS']
#
#
# Epoch 95
#
#
# batch 9500
#   minibatch loss: 1.5056864023208618
#   minibatch clustering accurracy: 0.57
#   sample 1:
#     enc input           > ['bus', 'cat', 'car', 'train']
#     dec train predicted > ['deer', 'bus', 'bus', 'train', 'EOS']
#   sample 2:
#     enc input           > ['pig', 'train', 'train', 'bus']
#     dec train predicted > ['deer', 'cat', 'train', 'train', 'EOS']
#   sample 3:
#     enc input           > ['bike', 'mouse', 'bus', 'car']
#     dec train predicted > ['deer', 'cat', 'bus', 'train', 'EOS']
#
#
# Epoch 96
#
#
# batch 9600
#   minibatch loss: 1.439990758895874
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['bike', 'car', 'train', 'PAD']
#     dec train predicted > ['mouse', 'train', 'car', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['deer', 'dog', 'cat', 'car']
#     dec train predicted > ['deer', 'motorcycle', 'deer', 'car', 'EOS']
#   sample 3:
#     enc input           > ['train', 'bike', 'car', 'deer']
#     dec train predicted > ['deer', 'pig', 'bike', 'dog', 'EOS']
#
#
# Epoch 97
# batch 9700
#   minibatch loss: 1.4616581201553345
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['mouse', 'deer', 'dog', 'car']
#     dec train predicted > ['deer', 'bike', 'bus', 'motorcycle', 'EOS']
#   sample 2:
#     enc input           > ['bus', 'bike', 'pig', 'bus']
#     dec train predicted > ['deer', 'bus', 'bus', 'car', 'EOS']
#   sample 3:
#     enc input           > ['bus', 'train', 'pig', 'bus']
#     dec train predicted > ['deer', 'bus', 'bus', 'car', 'EOS']
#
#
# Epoch 98
#
#
# batch 9800
#   minibatch loss: 1.4973316192626953
#   minibatch clustering accurracy: 0.58
#   sample 1:
#     enc input           > ['motorcycle', 'bus', 'train', 'PAD']
#     dec train predicted > ['mouse', 'motorcycle', 'motorcycle', 'EOS', 'PAD']
#   sample 2:
#     enc input           > ['car', 'deer', 'bike', 'car']
#     dec train predicted > ['deer', 'pig', 'deer', 'train', 'EOS']
#   sample 3:
#     enc input           > ['deer', 'dog', 'deer', 'PAD']
#     dec train predicted > ['mouse', 'deer', 'pig', 'EOS', 'PAD']
#
#
# Epoch 99
#
#
# batch 9900
#   minibatch loss: 1.4862558841705322
#   minibatch clustering accurracy: 0.56
#   sample 1:
#     enc input           > ['car', 'mouse', 'motorcycle', 'car']
#     dec train predicted > ['deer', 'car', 'deer', 'bike', 'EOS']
#   sample 2:
#     enc input           > ['bike', 'motorcycle', 'car', 'PAD']
#     dec train predicted > ['mouse', 'train', 'bike', 'EOS', 'PAD']
#   sample 3:
#     enc input           > ['cat', 'motorcycle', 'bike', 'car']
#     dec train predicted > ['deer', 'car', 'mouse', 'train', 'EOS']
#
#
# Epoch 100
#
#
# batch 10000
#   minibatch loss: 1.4798353910446167
#   minibatch clustering accurracy: 0.53
#   sample 1:
#     enc input           > ['deer', 'bus', 'motorcycle', 'train']
#     dec train predicted > ['deer', 'motorcycle', 'motorcycle', 'motorcycle', 'EOS']
#   sample 2:
#     enc input           > ['motorcycle', 'pig', 'motorcycle', 'motorcycle']
#     dec train predicted > ['deer', 'motorcycle', 'deer', 'bike', 'EOS']
#   sample 3:
#     enc input           > ['motorcycle', 'motorcycle', 'car', 'cat']
#     dec train predicted > ['deer', 'motorcycle', 'cat', 'cat', 'EOS']

# %% [markdown]
# ### Analysis

# %%
def plot_tracks():
    t = np.arange(len(loss_track))[::100]
    fig, ax1 = plt.subplots()
    color = 'r'
    ax1.set_xlabel('Combined Loss vs. Accuracy Tracks')
    ax1.set_ylabel('Combined Loss')
    ax1.plot(t, loss_track[::100], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax2 = ax1.twinx()
    color = 'b'
    ax2.set_ylabel('Clustering Accuracy', color=color)
    ax2.plot(t, accuracy_track[::100], color=color)
    ax2.tick_params(axis='y',labelcolor=color)
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ##### A. 3-5 sentence lengths

# %%
# 1st 100 epochs

plot_tracks()

# %%
# 2nd 100 epochs

plot_tracks()

# %%
# 3rd 100 epochs

plot_tracks()
